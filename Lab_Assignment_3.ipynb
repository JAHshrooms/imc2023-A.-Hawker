# %% [markdown]
# <a href="https://colab.research.google.com/github/JAHshrooms/imc2023-A.-Hawker/blob/main/Lab_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

#import audio files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 130 (delta 28), reused 18 (delta 18), pack-reused 96
# Receiving objects: 100% (130/130), 16.27 MiB | 11.61 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
def plotAudio2(sig,sampleRate,title):
    
    # this version expects the audio file to have already been opened by librosa
    
    # Adjust the x-axis to represent time
    time=np.arange(0,sig.shape[0])/sr
    
    # Scale the y-axis to represent amplitude from -1 to 1
    excursion=max(abs(sig))
    sigNew = sig / excursion
    
    # Label the x and y axes with variables
    xlabel = 'Time (seconds)'
    ylabel = 'Amplitude'

    # Plot the signal using the x and y axis variables    
    plt.plot(time,sigNew)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
def plotAudioFreDomain (sig,sr,title, winSize, specType):

  # create a normalized spectrogram with a small window size (256)
  spec2 = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)), ref=np.max)

  # plot the second spectogram with a linear frequency scaling
  librosa.display.specshow(spec2, y_axis=specType)
  plt.colorbar(format='%+2.0f dB')
  plt.title(title)
  plt.show()

# %%
def plotAudioFunc (sig,sr,title, winSize, specType): 
  plotAudio2 (sig, sr, title) 
  plotAudioFreDomain (sig,sr,title, winSize, specType)

# %%
sig,sr = librosa.load('imc2023/audioFiles/avm.wav')


title = 'Ave Maria' 
winSize = 2048
specType = 'linear'
plotAudioFunc (sig,sr,title, winSize, specType)

# %%
sig,sr = librosa.load('imc2023/audioFiles/avm.wav')

title = 'Ave Maria' 
winSize = 2048
specType = 'log'
plotAudioFunc (sig,sr,title, winSize, specType)

# %%
sig,sr = librosa.load('imc2023/audioFiles/avm.wav')


title = 'Ave Maria' 
winSize = 256
specType = 'linear'
plotAudioFunc (sig,sr,title, winSize, specType)

# %%
sig,sr = librosa.load('imc2023/audioFiles/avm.wav')


title = 'Ave Maria' 
winSize = 256
specType = 'log'
plotAudioFunc (sig,sr,title, winSize, specType)
